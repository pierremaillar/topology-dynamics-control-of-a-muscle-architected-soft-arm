# %%
from elastica._calculus import _isnan_check
from elastica.timestepper import extend_stepper_interface
from elastica import *
from elastica._elastica_numpy._rod._muscular_rod import MuscularRod
from Cases.arm_function import(
    DampingFilterBC,
    ExponentialDampingBC,
    DampingFilterBCRingRod,)

from elastica._linalg import _batch_norm

from Cases.post_processing import (plot_video_with_surface,plot_video_activation_muscle,)

import os
from elastica._rotations import _get_rotation_matrix

from itertools import groupby

from Connections import *

# %%
class RibbonSimulator_withOgden(BaseSystemCollection, Constraints, MemoryBlockConnections, Forcing, CallBacks):
    pass
    
n_elem = 50
start = np.array([0.0, 0.0, 0.0])
direction = np.array([0.0, 0.0, 1.0])
normal = np.array([0.0, 1.0, 0.0])
base_length = 0.5
base_radius = base_length /50
base_area = np.pi * base_radius ** 2
density = 1000
nu = 100
E = 1e6
poisson_ratio = 0.34
shear_modulus = E / (poisson_ratio + 1.0)

dl = base_length / n_elem
dt = 0.01 * dl

origin_force = np.array([0.0, 0.0, 0.0])
end_force = np.array([-0.0, 0.0, 0.0])
ramp_up_time = 5.0



Ribbon_Ogden = RibbonSimulator_withOgden()

shearable_rod = CosseratRod.straight_rod(
    n_elem,
    start,
    direction,
    normal,
    base_length,
    base_radius,
    density,
    youngs_modulus=E,
    shear_modulus=shear_modulus,
    poisson_ratio = nu,
    nu = nu,
)
Ribbon_Ogden.append(shearable_rod)


Ribbon_Ogden.constrain(shearable_rod).using(
    DampingFilterBC,
    constrained_position_idx=(0,),
    constrained_director_idx=(0,),
    filter_order=5,  # 10,
)


Ribbon_Ogden.constrain(shearable_rod).using(
    OneEndFixedRod, constrained_position_idx=(0,), constrained_director_idx=(0,)
)
Ribbon_Ogden.add_forcing_to(shearable_rod).using(
    EndpointForces, origin_force, end_force, ramp_up_time=ramp_up_time
)

gravitational_acc = -9.80665
Ribbon_Ogden.add_forcing_to(shearable_rod).using(
    GravityForces, acc_gravity=np.array([0.0, gravitational_acc, 0.0])
)

# %%
class RibbonOgdenCallBack(CallBackBaseClass):
    """
    Call back function for Bean Ogeden penetration
    """

    def __init__(self, step_skip: int, callback_params: dict):
        CallBackBaseClass.__init__(self)
        self.every = step_skip
        self.callback_params = callback_params

    def make_callback(self, system, time, current_step: int):

        if current_step % self.every == 0:

            self.callback_params["time"].append(time)
            self.callback_params["step"].append(current_step)
            self.callback_params["position"].append(system.position_collection.copy())
            self.callback_params["velocity"].append(system.velocity_collection.copy())
            self.callback_params["avg_velocity"].append(
                system.compute_velocity_center_of_mass()
            )

            self.callback_params["center_of_mass"].append(
                system.compute_position_center_of_mass()
            )
            self.callback_params["curvature"].append(system.kappa.copy())

            return


pp_list = defaultdict(list)
Ribbon_Ogden.collect_diagnostics(shearable_rod).using(
    RibbonOgdenCallBack, step_skip=10, callback_params=pp_list
)
print("Callback function added to the simulator")
# Out:
# Callback function added to the simulator

# %%
Ribbon_Ogden.finalize()
print("System finalized")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Ribbon_Ogden.finalize()
#       2 print("System finalized")
#
# File ~\OneDrive\Bureau\Projets\pyelastica_ribbon\topology-dynamics-control-of-a-muscle-architected-soft-arm\elastica\wrappers\base_system.py:158, in BaseSystemCollection.finalize(self)
#     155 finalize_methods = get_methods_from_feature_classes("_finalize")
#     157 # construct memory block
# --> 158 self._memory_blocks = construct_memory_block_structures(self._systems)
#     160 """
#     161 In case memory block have ring rod, then periodic boundaries have to be synched. In order to synchronize
#     162 periodic boundaries, a new constrain for memory block rod added called as _ConstrainPeriodicBoundaries. This
#     163 constrain will synchronize the only periodic boundaries of position, director, velocity and omega variables.
# ...
